# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/bank.csv')

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df.tail()
# Out:
#        age  balance  day  duration  campaign  pdays  previous  \
# 11157   33        1   20       257         1     -1         0
# 11158   39      733   16        83         4     -1         0
# 11159   32       29   19       156         2     -1         0
# 11160   43        0    8         9         2    172         5
# 11161   34        0    9       628         1     -1         0
#
#        job_blue-collar  job_entrepreneur  job_housemaid  ...  month_jun  \
# 11157             True             False          False  ...      False
# 11158            False             False          False  ...       True
# 11159            False             False          False  ...      False
# 11160            False             False          False  ...      False
# 11161            False             False          False  ...      False
#
#        month_mar  month_may  month_nov  month_oct  month_sep  poutcome_other  \
# 11157      False      False      False      False      False           False
# 11158      False      False      False      False      False           False
# 11159      False      False      False      False      False           False
# 11160      False       True      False      False      False           False
# 11161      False      False      False      False      False           False
#
#        poutcome_success  poutcome_unknown  deposit_yes
# 11157             False              True        False
# 11158             False              True        False
# 11159             False              True        False
# 11160             False             False        False
# 11161             False              True        False
#
# [5 rows x 43 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# max      854.000000     58.000000

# %%
df.shape
# Out:
# (11162, 17)

# %%
df
# Out:
#        age  balance  day  duration  campaign  pdays  previous  \
# 0       59     2343    5      1042         1     -1         0
# 1       56       45    5      1467         1     -1         0
# 2       41     1270    5      1389         1     -1         0
# 3       55     2476    5       579         1     -1         0
# 4       54      184    5       673         2     -1         0
# ...    ...      ...  ...       ...       ...    ...       ...
# 11157   33        1   20       257         1     -1         0
# 11158   39      733   16        83         4     -1         0
# 11159   32       29   19       156         2     -1         0
# 11160   43        0    8         9         2    172         5
# 11161   34        0    9       628         1     -1         0
#
#        job_blue-collar  job_entrepreneur  job_housemaid  ...  month_jun  \
# 0                False             False          False  ...      False
# 1                False             False          False  ...      False
# 2                False             False          False  ...      False
# 3                False             False          False  ...      False
# 4                False             False          False  ...      False
# ...                ...               ...            ...  ...        ...
# 11157             True             False          False  ...      False
# 11158            False             False          False  ...       True
# 11159            False             False          False  ...      False
# 11160            False             False          False  ...      False
# 11161            False             False          False  ...      False
#
#        month_mar  month_may  month_nov  month_oct  month_sep  poutcome_other  \
# 0          False       True      False      False      False           False
# 1          False       True      False      False      False           False
# 2          False       True      False      False      False           False
# 3          False       True      False      False      False           False
# 4          False       True      False      False      False           False
# ...          ...        ...        ...        ...        ...             ...
# 11157      False      False      False      False      False           False
# 11158      False      False      False      False      False           False
# 11159      False      False      False      False      False           False
# 11160      False       True      False      False      False           False
# 11161      False      False      False      False      False           False
#
#        poutcome_success  poutcome_unknown  deposit_yes
# 0                 False              True         True
# 1                 False              True         True
# 2                 False              True         True
# 3                 False              True         True
# 4                 False              True         True
# ...                 ...               ...          ...
# 11157             False              True        False
# 11158             False              True        False
# 11159             False              True        False
# 11160             False             False        False
# 11161             False              True        False
#
# [11162 rows x 43 columns]

# %%
df.isnull()
# Out:
#          age    job  marital  education  default  balance  housing   loan  \
# 0      False  False    False      False    False    False    False  False
# 1      False  False    False      False    False    False    False  False
# 2      False  False    False      False    False    False    False  False
# 3      False  False    False      False    False    False    False  False
# 4      False  False    False      False    False    False    False  False
# ...      ...    ...      ...        ...      ...      ...      ...    ...
# 11157  False  False    False      False    False    False    False  False
# 11158  False  False    False      False    False    False    False  False
# 11159  False  False    False      False    False    False    False  False
# 11160  False  False    False      False    False    False    False  False
# 11161  False  False    False      False    False    False    False  False
#
#        contact    day  month  duration  campaign  pdays  previous  poutcome  \
# 0        False  False  False     False     False  False     False     False
# 1        False  False  False     False     False  False     False     False
# 2        False  False  False     False     False  False     False     False
# 3        False  False  False     False     False  False     False     False
# 4        False  False  False     False     False  False     False     False
# ...        ...    ...    ...       ...       ...    ...       ...       ...
# 11157    False  False  False     False     False  False     False     False
# 11158    False  False  False     False     False  False     False     False
# 11159    False  False  False     False     False  False     False     False
# 11160    False  False  False     False     False  False     False     False
# 11161    False  False  False     False     False  False     False     False
#
#        deposit
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 11157    False
# 11158    False
# 11159    False
# 11160    False
# 11161    False
#
# [11162 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# age                    0
# balance                0
# day                    0
# duration               0
# campaign               0
# pdays                  0
# previous               0
# job_blue-collar        0
# job_entrepreneur       0
# job_housemaid          0
# job_management         0
# job_retired            0
# job_self-employed      0
# job_services           0
# job_student            0
# job_technician         0
# job_unemployed         0
# job_unknown            0
# marital_married        0
# marital_single         0
# education_secondary    0
# education_tertiary     0
# education_unknown      0
# default_yes            0
# housing_yes            0
# loan_yes               0
# contact_telephone      0
# contact_unknown        0
# month_aug              0
# month_dec              0
# month_feb              0
# month_jan              0
# month_jul              0
# month_jun              0
# month_mar              0
# month_may              0
# month_nov              0
# month_oct              0
# month_sep              0
# poutcome_other         0
# poutcome_success       0
# poutcome_unknown       0
# deposit_yes            0
# dtype: int64

# %%
print("Original column names:")
print(df.columns)

df.columns = df.columns.str.lower().str.replace(' ', '_')

print("\nUpdated column names:")
print(df.columns)
# Out:
# Original column names:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_married', 'marital_single', 'education_secondary',
#        'education_tertiary', 'education_unknown', 'default_yes', 'housing_yes',
#        'loan_yes', 'contact_telephone', 'contact_unknown', 'month_aug',
#        'month_dec', 'month_feb', 'month_jan', 'month_jul', 'month_jun',
#        'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
#        'poutcome_other', 'poutcome_success', 'poutcome_unknown',
#        'deposit_yes'],
#       dtype='object')
#
# Updated column names:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_married', 'marital_single', 'education_secondary',
#        'education_tertiary', 'education_unknown', 'default_yes', 'housing_yes',
#        'loan_yes', 'contact_telephone', 'contact_unknown', 'month_aug',
#        'month_dec', 'month_feb', 'month_jan', 'month_jul', 'month_jun',
#        'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
#        'poutcome_other', 'poutcome_success', 'poutcome_unknown',
#        'deposit_yes'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# age                    int64
# balance                int64
# day                    int64
# duration               int64
# campaign               int64
# pdays                  int64
# previous               int64
# job_blue-collar         bool
# job_entrepreneur        bool
# job_housemaid           bool
# job_management          bool
# job_retired             bool
# job_self-employed       bool
# job_services            bool
# job_student             bool
# job_technician          bool
# job_unemployed          bool
# job_unknown             bool
# marital_married         bool
# marital_single          bool
# education_secondary     bool
# education_tertiary      bool
# education_unknown       bool
# default_yes             bool
# housing_yes             bool
# loan_yes                bool
# contact_telephone       bool
# contact_unknown         bool
# month_aug               bool
# month_dec               bool
# month_feb               bool
# month_jan               bool
# month_jul               bool
# month_jun               bool
# month_mar               bool
# month_may               bool
# month_nov               bool
# month_oct               bool
# month_sep               bool
# poutcome_other          bool
# poutcome_success        bool
# poutcome_unknown        bool
# deposit_yes             bool
# dtype: object

# %%
print("Updated column names:")
print(df.columns)
print("\nUpdated data types:")
print(df.dtypes)
# Out:
# Updated column names:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_married', 'marital_single', 'education_secondary',
#        'education_tertiary', 'education_unknown', 'default_yes', 'housing_yes',
#        'loan_yes', 'contact_telephone', 'contact_unknown', 'month_aug',
#        'month_dec', 'month_feb', 'month_jan', 'month_jul', 'month_jun',
#        'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
#        'poutcome_other', 'poutcome_success', 'poutcome_unknown',
#        'deposit_yes'],
#       dtype='object')
#
# Updated data types:
# age                    int64
# balance                int64
# day                    int64
# duration               int64
# campaign               int64
# pdays                  int64
# previous               int64
# job_blue-collar         bool
# job_entrepreneur        bool
# job_housemaid           bool
# job_management          bool
# job_retired             bool
# job_self-employed       bool
# job_services            bool
# job_student             bool
# job_technician          bool
# job_unemployed          bool
# job_unknown             bool
# marital_married         bool
# marital_single          bool
# education_secondary     bool
# education_tertiary      bool
# education_unknown       bool
# default_yes             bool
# housing_yes             bool
# loan_yes                bool
# contact_telephone       bool
# contact_unknown         bool
# month_aug               bool
# month_dec               bool
# month_feb               bool
# month_jan               bool
# month_jul               bool
# month_jun               bool
# month_mar               bool
# month_may               bool
# month_nov               bool
# month_oct               bool
# month_sep               bool
# poutcome_other          bool
# poutcome_success        bool
# poutcome_unknown        bool
# deposit_yes             bool
# dtype: object

# %%
initial_rows = df.shape[0]
df = df.drop_duplicates()
rows_after_dropping = df.shape[0]

print(f"Number of rows before dropping duplicates: {initial_rows}")
print(f"Number of rows after dropping duplicates: {rows_after_dropping}")
print(f"Number of duplicate rows dropped: {initial_rows - rows_after_dropping}")
# Out:
# Number of rows before dropping duplicates: 11162
# Number of rows after dropping duplicates: 11162
# Number of duplicate rows dropped: 0

# %%
categorical_cols = df.select_dtypes(include='object').columns
print("Categorical columns:")
for col in categorical_cols:
    print(col)
# Out:
# Categorical columns:

# %%
print(f"\n--- KPI 1: Transaction Success Rate (TSR) ---")
print(f"Total Final Transactions: {total_transactions}")
print(f"Successful Transactions: {successful_transactions}")
print(f"Transaction Success Rate: {success_rate:.2f}%") # just to check
# Out:
# --- KPI 1: Transaction Success Rate (TSR) ---
# Total Final Transactions: 11162
# Successful Transactions: 5289
# Transaction Success Rate: 47.38%

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Numerical columns:")
print(numerical_cols)
# Out:
# Numerical columns:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
print(f"\n--- KPI 2: Average Transaction Value (ATV) ---")
print(f"Average Transaction Value (ATV): ${avg_transaction_value:,.2f}") # just for check
# Out:
# --- KPI 2: Average Transaction Value (ATV) ---
# Average Transaction Value (ATV): $1,528.54

# %%
# Calculate Average Transaction Value (ATV)
avg_transaction_value = df['balance'].mean()

# %%
# 3. Basic User Segmentation
user_segmentation = df.groupby('age').agg(
    transaction_count=('balance', 'count'),
    total_amount_sent=('balance', 'sum'),
    average_amount_sent=('balance', 'mean')
).reset_index()

# Merge the segmentation features back into the main DataFrame - Note: This merge will create many rows since we are merging on 'age'
# df = df.merge(user_segmentation, on='age', how='left') # Uncomment and run if you want to merge
display(user_segmentation.head())
# Out:
#    age  transaction_count  total_amount_sent  average_amount_sent
# 0   18                  8               1896           237.000000
# 1   19                 13               3681           283.153846
# 2   20                 20              20264          1013.200000
# 3   21                 30              31926          1064.200000
# 4   22                 48              40559           844.979167

# %%
# Print columns to confirm success
print("Columns after successful merge:")
print(df.columns.tolist())
# Out:
# Columns after successful merge:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired', 'job_self-employed', 'job_services', 'job_student', 'job_technician', 'job_unemployed', 'job_unknown', 'marital_married', 'marital_single', 'education_secondary', 'education_tertiary', 'education_unknown', 'default_yes', 'housing_yes', 'loan_yes', 'contact_telephone', 'contact_unknown', 'month_aug', 'month_dec', 'month_feb', 'month_jan', 'month_jul', 'month_jun', 'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep', 'poutcome_other', 'poutcome_success', 'poutcome_unknown', 'deposit_yes']

# %%
# --- PHASE 3: FINAL MODEL PREPARATION ---

# 1. One-Hot Encode the categorical columns
# This converts categories into numerical features
categorical_cols = df.select_dtypes(include='object').columns
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

print("✅ Categorical Encoding and Cleanup Complete.")
print("The data is now ready for scaling and model training.")
print("Remaining features:", df.columns.tolist())
# Out:
# ✅ Categorical Encoding and Cleanup Complete.
# The data is now ready for scaling and model training.
# Remaining features: ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired', 'job_self-employed', 'job_services', 'job_student', 'job_technician', 'job_unemployed', 'job_unknown', 'marital_married', 'marital_single', 'education_secondary', 'education_tertiary', 'education_unknown', 'default_yes', 'housing_yes', 'loan_yes', 'contact_telephone', 'contact_unknown', 'month_aug', 'month_dec', 'month_feb', 'month_jan', 'month_jul', 'month_jun', 'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep', 'poutcome_other', 'poutcome_success', 'poutcome_unknown', 'deposit_yes']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# --- PHASE 3: MODEL BUILDING ---

# 1. Define Features (X) and Target (y)
# 'deposit_yes' (0/1) is the column we want to predict.
y = df['deposit_yes']
X = df.drop('deposit_yes', axis=1)

# 2. Scaling Numerical Features
# Identify columns that need scaling (all features except the new binary Transaction_Type columns)
# We can simply select all remaining columns in X for safety, as StandardScaler works fine on 0s and 1s too.
numerical_cols = X.columns
scaler = StandardScaler()
X[numerical_cols] = scaler.fit_transform(X[numerical_cols])

print("Features scaled successfully.")

# 3. Split the Data (Training and Testing)
# Use a 70/30 split for training and testing the model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Data split: Training samples={len(X_train)}, Testing samples={len(X_test)}")

# 4. Train a Model (Using Random Forest Classifier)
# Random Forest is a robust choice for imbalanced fraud data
model = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
model.fit(X_train, y_train)

print("\nRandom Forest Model trained successfully.")
# Out:
# Features scaled successfully.
# Data split: Training samples=7813, Testing samples=3349
#
# Random Forest Model trained successfully.

# %%
import numpy as np

# Assuming 'model' (Random Forest) and 'X' (Scaled Features) are still available

# 1. Extract Feature Importance
feature_importances = pd.Series(model.feature_importances_, index=X.columns)

# 2. Sort and select the Top 10 features
top_10_features = feature_importances.sort_values(ascending=False).head(10)

print("\n--- Top 10 Most Important Features ---")
print(top_10_features.to_string(float_format='{:.4f}'.format))
# Out:
# --- Top 10 Most Important Features ---
# duration           0.3437
# balance            0.0822
# age                0.0777
# day                0.0700
# campaign           0.0366
# pdays              0.0359
# contact_unknown    0.0356
# poutcome_success   0.0304
# housing_yes        0.0254
# previous           0.0194

# %%
# --- PHASE 3: MODEL EVALUATION ---

# 1. Make predictions on the test set
y_pred = model.predict(X_test)

# 2. Print the Classification Report and Confusion Matrix
print("\n--- Model Performance Evaluation ---")
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
# Note: The Confusion Matrix shows True Negatives, False Positives, False Negatives, True Positives
print(confusion_matrix(y_test, y_pred))
# Out:
# --- Model Performance Evaluation ---
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.87      0.82      0.85      1742
#         True       0.82      0.87      0.84      1607
#
#     accuracy                           0.84      3349
#    macro avg       0.84      0.84      0.84      3349
# weighted avg       0.85      0.84      0.84      3349
#
# Confusion Matrix:
# [[1431  311]
#  [ 213 1394]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming top_10_features is the Pandas Series you calculated earlier
# The updated code to suppress the FutureWarning
plt.figure(figsize=(10, 6))
# Assign the 'y' variable (top_10_features.index) to 'hue' to satisfy the new requirement
sns.barplot(x=top_10_features.values, y=top_10_features.index, hue=top_10_features.index, palette='viridis', legend=False)
plt.title('Top 10 Feature Importance Scores (Random Forest)')
plt.xlabel('Importance Score')
plt.ylabel('Feature')
plt.show()

# %%
# Assuming 'y' (the target variable df['Status_Code']) is still available

# 1. Anomaly Class Distribution (Bar Chart/Count Plot)
# The correct way to write the countplot to avoid the warning
plt.figure(figsize=(6, 4))
sns.countplot(x=y, palette='coolwarm', hue=y, legend=False) # Added hue=y and legend=False
plt.title('Distribution of Transaction Status (0: Normal, 1: Anomaly)')
plt.xticks([0, 1], ['Normal (0)', 'Anomaly (1)'])
plt.ylabel('Count')
plt.show()

# %%
# The box plot
plt.figure(figsize=(10, 6))
# Focus on the top feature: Sender_Balance_Before
sns.boxplot(x='deposit_yes', y='balance', data=df)
plt.title('Balance Distribution by Deposit Status')
plt.xticks([0, 1], ['No Deposit (0)', 'Deposit (1)'])

# Since the outlier transactions of $10M will skew the plot, limit the y-axis
# to visualize the bulk of the data (e.g., up to $1M).
# If you don't use this line, the box plots will be flat due to the outliers.
plt.ylim(0, 100000)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.boxplot(y=df['balance'])
plt.title('Box Plot of Balance')
plt.ylabel('Balance')

plt.subplot(1, 2, 2)
sns.histplot(df['balance'], kde=True)
plt.title('Histogram of Balance')
plt.xlabel('Balance')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
